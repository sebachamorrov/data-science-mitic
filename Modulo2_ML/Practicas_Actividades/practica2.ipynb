# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('C:/Users/SebastianChamorro/OneDrive/Documentos/Cursos/0-DATASETS/bank-full.csv', delimiter=';')
df['y'].value_counts()
# Out:
# y
# no     39922
# yes     5289
# Name: count, dtype: int64

# %%
df = df.query('y == "yes"')

# %%
df_num = df.select_dtypes(int)
#df_num = df_num.query('y = yes')
df_num = df_num.query('age < 70 & balance < 20000 & balance > 5000')
df_num.head(2)
# Out:
#       age  balance  day  duration  campaign  pdays  previous
# 569    28     5090    6      1297         3     -1         0
# 3004   51     7180   14       927         1     -1         0

# %%
# Crear subgráficas
fig, axs = plt.subplots(1, 2, figsize=(12, 5))  # 1 fila, 2 columnas

# Histograma
datos = df_num['age']  # Se cargan los datos
n, bins, patches = axs[0].hist(datos, bins=6, rwidth=0.5)  # Histograma
axs[0].set_xlabel("Age")  # Etiqueta del eje X
axs[0].set_ylabel("Frecuencia")  # Etiqueta del eje Y
axs[0].set_title("Histograma Age")  # Título del gráfico

# Etiquetas en el histograma
for count, x in zip(n, bins):
    axs[0].text(x + 0.05, count, str(int(count)), ha='center', va='bottom')

# Boxplot
axs[1].boxplot(datos)  # Boxplot
axs[1].set_ylabel("Age")  # Etiqueta del eje Y
axs[1].set_title("Age")  # Título del gráfico

# Calcular los cuartiles
Q1 = datos.quantile(0.25)  # Primer cuartil
Q2 = datos.median()  # Mediana (segundo cuartil)
Q3 = datos.quantile(0.75)  # Tercer cuartil

# Etiquetas de datos para los cuartiles
axs[1].text(1.1, Q1, f'Q1: {Q1:.2f}', fontsize=10, ha='left')
axs[1].text(1.1, Q2, f'Median: {Q2:.2f}', fontsize=10, ha='left')
axs[1].text(1.1, Q3, f'Q3: {Q3:.2f}', fontsize=10, ha='left')

# Ajustar el espacio entre gráficos
plt.tight_layout()

# Mostrar gráfico
plt.show()

# %%
# Crear subgráficas
fig, axs = plt.subplots(1, 2, figsize=(12, 5))  # 1 fila, 2 columnas

# Histograma
datos = df_num['balance']  # Se cargan los datos
n, bins, patches = axs[0].hist(datos, bins=6, rwidth=0.5)  # Histograma
axs[0].set_xlabel("balance")  # Etiqueta del eje X
axs[0].set_ylabel("Frecuencia")  # Etiqueta del eje Y
axs[0].set_title("Histograma balance")  # Título del gráfico

# Etiquetas en el histograma
for count, x in zip(n, bins):
    axs[0].text(x + 0.05, count, str(int(count)), ha='center', va='bottom')

# Boxplot
axs[1].boxplot(datos)  # Boxplot
axs[1].set_ylabel("balance")  # Etiqueta del eje Y
axs[1].set_title("balance")  # Título del gráfico

# Calcular los cuartiles
Q1 = datos.quantile(0.25)  # Primer cuartil
Q2 = datos.median()  # Mediana (segundo cuartil)
Q3 = datos.quantile(0.75)  # Tercer cuartil

# Etiquetas de datos para los cuartiles
axs[1].text(1.1, Q1, f'Q1: {Q1:.2f}', fontsize=10, ha='left')
axs[1].text(1.1, Q2, f'Median: {Q2:.2f}', fontsize=10, ha='left')
axs[1].text(1.1, Q3, f'Q3: {Q3:.2f}', fontsize=10, ha='left')

# Ajustar el espacio entre gráficos
plt.tight_layout()

# Mostrar gráfico
plt.show()

# %%
# Crear subgráficas
fig, axs = plt.subplots(1, 2, figsize=(12, 5))  # 1 fila, 2 columnas

# Histograma
datos = df_num['day']  # Se cargan los datos
n, bins, patches = axs[0].hist(datos, bins=6, rwidth=0.5)  # Histograma
axs[0].set_xlabel("day")  # Etiqueta del eje X
axs[0].set_ylabel("Frecuencia")  # Etiqueta del eje Y
axs[0].set_title("Histograma day")  # Título del gráfico

# Etiquetas en el histograma
for count, x in zip(n, bins):
    axs[0].text(x + 0.05, count, str(int(count)), ha='center', va='bottom')

# Boxplot
axs[1].boxplot(datos)  # Boxplot
axs[1].set_ylabel("day")  # Etiqueta del eje Y
axs[1].set_title("day")  # Título del gráfico

# Calcular los cuartiles
Q1 = datos.quantile(0.25)  # Primer cuartil
Q2 = datos.median()  # Mediana (segundo cuartil)
Q3 = datos.quantile(0.75)  # Tercer cuartil

# Etiquetas de datos para los cuartiles
axs[1].text(1.1, Q1, f'Q1: {Q1:.2f}', fontsize=10, ha='left')
axs[1].text(1.1, Q2, f'Median: {Q2:.2f}', fontsize=10, ha='left')
axs[1].text(1.1, Q3, f'Q3: {Q3:.2f}', fontsize=10, ha='left')

# Ajustar el espacio entre gráficos
plt.tight_layout()

# Mostrar gráfico
plt.show()

# %%
# Crear subgráficas
fig, axs = plt.subplots(1, 2, figsize=(12, 5))  # 1 fila, 2 columnas

# Histograma
datos = df_num['duration']  # Se cargan los datos
n, bins, patches = axs[0].hist(datos, bins=6, rwidth=0.5)  # Histograma
axs[0].set_xlabel("duration")  # Etiqueta del eje X
axs[0].set_ylabel("Frecuencia")  # Etiqueta del eje Y
axs[0].set_title("Histograma duration")  # Título del gráfico

# Etiquetas en el histograma
for count, x in zip(n, bins):
    axs[0].text(x + 0.05, count, str(int(count)), ha='center', va='bottom')

# Boxplot
axs[1].boxplot(datos)  # Boxplot
axs[1].set_ylabel("duration")  # Etiqueta del eje Y
axs[1].set_title("duration")  # Título del gráfico

# Calcular los cuartiles
Q1 = datos.quantile(0.25)  # Primer cuartil
Q2 = datos.median()  # Mediana (segundo cuartil)
Q3 = datos.quantile(0.75)  # Tercer cuartil

# Etiquetas de datos para los cuartiles
axs[1].text(1.1, Q1, f'Q1: {Q1:.2f}', fontsize=10, ha='left')
axs[1].text(1.1, Q2, f'Median: {Q2:.2f}', fontsize=10, ha='left')
axs[1].text(1.1, Q3, f'Q3: {Q3:.2f}', fontsize=10, ha='left')

# Ajustar el espacio entre gráficos
plt.tight_layout()

# Mostrar gráfico
plt.show()

# %%
# Crear subgráficas
fig, axs = plt.subplots(1, 2, figsize=(12, 5))  # 1 fila, 2 columnas

# Histograma
datos = df_num['campaign']  # Se cargan los datos
n, bins, patches = axs[0].hist(datos, bins=6, rwidth=0.5)  # Histograma
axs[0].set_xlabel("campaign")  # Etiqueta del eje X
axs[0].set_ylabel("Frecuencia")  # Etiqueta del eje Y
axs[0].set_title("Histograma campaign")  # Título del gráfico

# Etiquetas en el histograma
for count, x in zip(n, bins):
    axs[0].text(x + 0.05, count, str(int(count)), ha='center', va='bottom')

# Boxplot
axs[1].boxplot(datos)  # Boxplot
axs[1].set_ylabel("campaign")  # Etiqueta del eje Y
axs[1].set_title("campaign")  # Título del gráfico

# Calcular los cuartiles
Q1 = datos.quantile(0.25)  # Primer cuartil
Q2 = datos.median()  # Mediana (segundo cuartil)
Q3 = datos.quantile(0.75)  # Tercer cuartil

# Etiquetas de datos para los cuartiles
axs[1].text(1.1, Q1, f'Q1: {Q1:.2f}', fontsize=10, ha='left')
axs[1].text(1.1, Q2, f'Median: {Q2:.2f}', fontsize=10, ha='left')
axs[1].text(1.1, Q3, f'Q3: {Q3:.2f}', fontsize=10, ha='left')

# Ajustar el espacio entre gráficos
plt.tight_layout()

# Mostrar gráfico
plt.show()

# %%
# Crear subgráficas
fig, axs = plt.subplots(1, 2, figsize=(12, 5))  # 1 fila, 2 columnas

# Histograma
datos = df_num['pdays']  # Se cargan los datos
n, bins, patches = axs[0].hist(datos, bins=6, rwidth=0.5)  # Histograma
axs[0].set_xlabel("pdays")  # Etiqueta del eje X
axs[0].set_ylabel("Frecuencia")  # Etiqueta del eje Y
axs[0].set_title("Histograma pdays")  # Título del gráfico

# Etiquetas en el histograma
for count, x in zip(n, bins):
    axs[0].text(x + 0.05, count, str(int(count)), ha='center', va='bottom')

# Boxplot
axs[1].boxplot(datos)  # Boxplot
axs[1].set_ylabel("pdays")  # Etiqueta del eje Y
axs[1].set_title("pdays")  # Título del gráfico

# Calcular los cuartiles
Q1 = datos.quantile(0.25)  # Primer cuartil
Q2 = datos.median()  # Mediana (segundo cuartil)
Q3 = datos.quantile(0.75)  # Tercer cuartil

# Etiquetas de datos para los cuartiles
axs[1].text(1.1, Q1, f'Q1: {Q1:.2f}', fontsize=10, ha='left')
axs[1].text(1.1, Q2, f'Median: {Q2:.2f}', fontsize=10, ha='left')
axs[1].text(1.1, Q3, f'Q3: {Q3:.2f}', fontsize=10, ha='left')

# Ajustar el espacio entre gráficos
plt.tight_layout()

# Mostrar gráfico
plt.show()

# %%
# Crear subgráficas
fig, axs = plt.subplots(1, 2, figsize=(12, 5))  # 1 fila, 2 columnas

# Histograma
datos = df_num['previous']  # Se cargan los datos
n, bins, patches = axs[0].hist(datos, bins=6, rwidth=0.5)  # Histograma
axs[0].set_xlabel("previous")  # Etiqueta del eje X
axs[0].set_ylabel("Frecuencia")  # Etiqueta del eje Y
axs[0].set_title("Histograma previous")  # Título del gráfico

# Etiquetas en el histograma
for count, x in zip(n, bins):
    axs[0].text(x + 0.05, count, str(int(count)), ha='center', va='bottom')

# Boxplot
axs[1].boxplot(datos)  # Boxplot
axs[1].set_ylabel("previous")  # Etiqueta del eje Y
axs[1].set_title("previous")  # Título del gráfico

# Calcular los cuartiles
Q1 = datos.quantile(0.25)  # Primer cuartil
Q2 = datos.median()  # Mediana (segundo cuartil)
Q3 = datos.quantile(0.75)  # Tercer cuartil

# Etiquetas de datos para los cuartiles
axs[1].text(1.1, Q1, f'Q1: {Q1:.2f}', fontsize=10, ha='left')
axs[1].text(1.1, Q2, f'Median: {Q2:.2f}', fontsize=10, ha='left')
axs[1].text(1.1, Q3, f'Q3: {Q3:.2f}', fontsize=10, ha='left')

# Ajustar el espacio entre gráficos
plt.tight_layout()

# Mostrar gráfico
plt.show()

# %%
# Cálculo de la correlación de Pearson
correlation_matrix = df_num.corr(method='pearson')
print(correlation_matrix)
# Out:
#                age   balance       day  duration  campaign     pdays  previous
# age       1.000000  0.035038  0.006002  0.025829 -0.052834 -0.037427 -0.046123
# balance   0.035038  1.000000 -0.017697 -0.062093  0.083501 -0.027548 -0.046239
# day       0.006002 -0.017697  1.000000  0.021684  0.090939 -0.022720 -0.025745
# duration  0.025829 -0.062093  0.021684  1.000000  0.177153 -0.062284 -0.073093
# campaign -0.052834  0.083501  0.090939  0.177153  1.000000 -0.075041 -0.033433
# pdays    -0.037427 -0.027548 -0.022720 -0.062284 -0.075041  1.000000  0.453707
# previous -0.046123 -0.046239 -0.025745 -0.073093 -0.033433  0.453707  1.000000

# %%
# Crear un mapa de calor para la matriz de correlación de Pearson
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0)
plt.title("Mapa de Calor de la Correlación de Pearson")
plt.show()
